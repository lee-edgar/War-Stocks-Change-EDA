# %%
import sklearn
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
## 1. 전쟁데이터 데이터프레임만들기

# %%
ls_war = pd.read_excel("datas/list_of_war.xlsx")
ls_war.head(3
           )
# Out:
#   Unnamed: 0 Unnamed: 1      Unnamed: 2 Unnamed: 3              Unnamed: 4  \
# 0       발발시점       종료시점            갈등이름       갈등종류                      위치
# 1     2001.9     2003.3       쿠르드이슬람교분쟁         민족               이라크 쿠르디스탄
# 2  2001.9.11         현재          테러와의전쟁         테러                     글로벌
# 3  2002.1.15  2015.2.24     영원한자유작전-필리핀         테러              만다나오,필리핀제도
# 4  2002.10.7         현재  영원한자유작전-아프리카의뿔         테러  아프리카의뿔,아덴만,Guardafui채널
#
#                                           Unnamed: 5  \
# 0                                                참전국
# 1                             쿠르드족애국연합,쿠르디스탄민주당,미국육군
# 2  미국,영국,프랑스,러시아,알바니아,벨기에,불가리아,캐나다,크로아티아,체코공화국,덴마...
# 3                                          필리핀공화국,미국
# 4  벨기에,캐나다,덴마크,프랑스,독일,그리스,이탈리아,네덜란드,포르투갈,스페인,터키,영...
#
#                                           Unnamed: 6 Unnamed: 7  \
# 0                                                상대국       전쟁원인
# 1                           알카에다,ISIL,아프간탈레반,파키스탄탈레반        NaN
# 2                                                NaN        NaN
# 3                                            지하디스크그룹        NaN
# 4  이라크,알카에다,Harkat al-Shabaad Mujahedeen, al-Itih...        NaN
#
#                  Unnamed: 8 Unnamed: 9  \
# 0                     힘_참전국     병력_참전국
# 1  KDP및PUK:70000 ~ 40명의 미국인      70000
# 2                       NaN        NaN
# 3  미국:500-6000, 필리핀:110,000     110500
# 4              소말리아에서개인500명        500
#
#                                        Unnamed: 10 Unnamed: 11  \
# 0                                            힘_상대국      병력_상대국
# 1  Ansar al-Islam : 700-1000명의 전투기, IUM : 40명의 전투기        1000
# 2                                              NaN         NaN
# 3                                             5300        5300
# 4                                              NaN         NaN
#
#                       Unnamed: 12  \
# 0                      사상자및손실_참전국
# 1                 최소45명사망 및 93명부상
# 2                             NaN
# 3                           17명사망
# 4  미국2명사망,6명부상,전투외사망자33명, 한국 3명부상
#
#                                         Unnamed: 13  Unnamed: 14
# 0                                        사상자및손실_상대국          NaN
# 1                                          200명이상사망          NaN
# 2                                               NaN          NaN
# 3                                               NaN          NaN
# 4  이슬람반군:소말리이아에서 1,230~1,367명의무장세력사망, 해적:1,200명이상체포          NaN

# %%
ls_war.loc[0]
# Out:
# Unnamed: 0           발발시점
# Unnamed: 1           종료시점
# Unnamed: 2           갈등이름
# Unnamed: 3           갈등종류
# Unnamed: 4             위치
# Unnamed: 5            참전국
# Unnamed: 6            상대국
# Unnamed: 7           전쟁원인
# Unnamed: 8          힘_참전국
# Unnamed: 9         병력_참전국
# Unnamed: 10         힘_상대국
# Unnamed: 11        병력_상대국
# Unnamed: 12    사상자및손실_참전국
# Unnamed: 13    사상자및손실_상대국
# Unnamed: 14           NaN
# Name: 0, dtype: object

# %%
ls_war_rename = ls_war.rename(columns  = {"Unnamed: 0" : "발발시점",
                          "Unnamed: 1" : "종료시점",
                          "Unnamed: 2" : "갈등이름",
                          "Unnamed: 3" : "갈등종류",
                          "Unnamed: 4" : "위치",
                          "Unnamed: 5" : "참전국",
                          "Unnamed: 6" : "상대국",
                          "Unnamed: 7" : "전쟁원인",
                          "Unnamed: 8" : "힘_참전국",
                          "Unnamed: 9" : "병력_참전국",
                          "Unnamed: 10" : "힘_상대국",
                          "Unnamed: 11" : "병력_상대국",
                          "Unnamed: 12" : "사상자및손실_참전국",
                          "Unnamed: 13" : "사상자및손실_상대국"}, inplace=False)

ls_war_rename = ls_war_rename.drop(index=[0])
ls_war_rename.head(2)
# Out:
#         발발시점    종료시점       갈등이름 갈등종류         위치  \
# 1     2001.9  2003.3  쿠르드이슬람교분쟁   민족  이라크 쿠르디스탄
# 2  2001.9.11      현재     테러와의전쟁   테러        글로벌
#
#                                                  참전국  \
# 1                             쿠르드족애국연합,쿠르디스탄민주당,미국육군
# 2  미국,영국,프랑스,러시아,알바니아,벨기에,불가리아,캐나다,크로아티아,체코공화국,덴마...
#
#                         상대국 전쟁원인                     힘_참전국 병력_참전국  \
# 1  알카에다,ISIL,아프간탈레반,파키스탄탈레반  NaN  KDP및PUK:70000 ~ 40명의 미국인  70000
# 2                       NaN  NaN                       NaN    NaN
#
#                                              힘_상대국 병력_상대국       사상자및손실_참전국  \
# 1  Ansar al-Islam : 700-1000명의 전투기, IUM : 40명의 전투기   1000  최소45명사망 및 93명부상
# 2                                              NaN    NaN              NaN
#
#   사상자및손실_상대국  Unnamed: 14
# 1   200명이상사망          NaN
# 2        NaN          NaN

# %%
ls_war2 = ls_war_rename.drop(['전쟁원인','힘_참전국','힘_상대국','사상자및손실_참전국','사상자및손실_상대국','Unnamed: 14'], axis=1)
ls_war2.head()
# Out:
#         발발시점       종료시점            갈등이름 갈등종류                      위치  \
# 1     2001.9     2003.3       쿠르드이슬람교분쟁   민족               이라크 쿠르디스탄
# 2  2001.9.11         현재          테러와의전쟁   테러                     글로벌
# 3  2002.1.15  2015.2.24     영원한자유작전-필리핀   테러              만다나오,필리핀제도
# 4  2002.10.7         현재  영원한자유작전-아프리카의뿔   테러  아프리카의뿔,아덴만,Guardafui채널
# 5       2006         현재           탈레반반란   테러                  아프가니스탄
#
#                                                  참전국  \
# 1                             쿠르드족애국연합,쿠르디스탄민주당,미국육군
# 2  미국,영국,프랑스,러시아,알바니아,벨기에,불가리아,캐나다,크로아티아,체코공화국,덴마...
# 3                                          필리핀공화국,미국
# 4  벨기에,캐나다,덴마크,프랑스,독일,그리스,이탈리아,네덜란드,포르투갈,스페인,터키,영...
# 5  아프가니스탄,호주,크로아티아,체코공화국,그루지야,독일,이탈리아,루마니아,스페인,터키...
#
#                                                  상대국  병력_참전국 병력_상대국
# 1                           알카에다,ISIL,아프간탈레반,파키스탄탈레반   70000   1000
# 2                                                NaN     NaN    NaN
# 3                                            지하디스크그룹  110500   5300
# 4  이라크,알카에다,Harkat al-Shabaad Mujahedeen, al-Itih...     500    NaN
# 5  탈레반, 파키스탄, 러시아, 중국, 카타르, 이란, 사우디아라비아, Hezb-e-I...  352000  64000

# %%
## 2. 참전국-상대국병력 합산해서 전쟁규모 컬럼만들기

# %%
ls_war2['전쟁규모'] = ls_war2['병력_참전국'] + ls_war2['병력_상대국']
ls_war2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 1 to 30
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   발발시점    30 non-null     object
#  1   종료시점    30 non-null     object
#  2   갈등이름    30 non-null     object
#  3   갈등종류    30 non-null     object
#  4   위치      30 non-null     object
#  5   참전국     30 non-null     object
#  6   상대국     28 non-null     object
#  7   병력_참전국  27 non-null     object
#  8   병력_상대국  24 non-null     object
#  9   전쟁규모    24 non-null     object
# dtypes: object(10)
# memory usage: 3.6+ KB

# %%
ls_war2.head(2)
# Out:
#         발발시점    종료시점       갈등이름 갈등종류         위치  \
# 1     2001.9  2003.3  쿠르드이슬람교분쟁   민족  이라크 쿠르디스탄
# 2  2001.9.11      현재     테러와의전쟁   테러        글로벌
#
#                                                  참전국  \
# 1                             쿠르드족애국연합,쿠르디스탄민주당,미국육군
# 2  미국,영국,프랑스,러시아,알바니아,벨기에,불가리아,캐나다,크로아티아,체코공화국,덴마...
#
#                         상대국 병력_참전국 병력_상대국   전쟁규모
# 1  알카에다,ISIL,아프간탈레반,파키스탄탈레반  70000   1000  71000
# 2                       NaN    NaN    NaN    NaN

# %%
ls_war2['참전국']
# Out:
# 1                                쿠르드족애국연합,쿠르디스탄민주당,미국육군
# 2     미국,영국,프랑스,러시아,알바니아,벨기에,불가리아,캐나다,크로아티아,체코공화국,덴마...
# 3                                             필리핀공화국,미국
# 4     벨기에,캐나다,덴마크,프랑스,독일,그리스,이탈리아,네덜란드,포르투갈,스페인,터키,영...
# 5     아프가니스탄,호주,크로아티아,체코공화국,그루지야,독일,이탈리아,루마니아,스페인,터키...
# 6     미국,영국,호주,루마니아,아제르바이잔,쿠웨이트,에스토니아,엘살바도르,불가리아,몰도바...
# 7                                   쿠르드족자유생활당, 이스라엘, 미국
# 8                         예멘,사우디아라비아,벨라루스,요르단,모로코,수단,미국
# 9                                          파라과이,미국,콜롬비아
# 10                                           파타, 미국, 영국
# 11                                              이스라엘,미국
# 12                         이라크보안군,미국,영국,다른연합국,Peshmerga
# 13                                       멕시코,미국,콜롬비아,호주
# 14                     에티오피아,미국,우간다,부룬디,나이지리아,가나,말라위,영국
# 15    알제리,모로코,모리타니,튀니지,부키나파소,차드,말리,니제르,나이지리아,세네갈,미국,...
# 16                    코모로,세네갈,수단,탄자니아,프랑스,리비아아랍자마히리야,미국
# 17    나이지리아,카메룬,차드,니제르,베기에,베냉,캐나다,중국,파키스탄,콜롬비아,이집트,프...
# 18     소말리아,부룬디지부티,에티오피아,가나,케냐,나이지리아,세에라리온,우간다,미국,영국,EU
# 19                                              자메이카,미국
# 20    국가전환위원회, 카타르, 벨기에, 불가리아, 캐나다, 덴마크,프랑스,그리스,이탈리아...
# 21    미국,프랑스,요르단,독일,네델란드,UAE,호주,벨기에,바레인,덴마크,모로코,카타르,캐나다
# 22    레바논,호주,캐나다,중국,키프로스,체코공화국,이집트프랑스,독일,이란,이탈리아,요르단...
# 23    말리,프랑스,베냉,부키나파소,카보베르데,감비아,가나,기니,기니비사우,아이보리해안,라...
# 24    이라크 투르크멘전선, 리와 아부알파달알압바스,이라크공산당, 미국,영국,호주,프랑스,...
# 25    리비아국군,리비아공군,진탄여단,러시아인PMC JEM, SLM/A-민나위, 이집트, ...
# 26    미국,호주,캐나다,벨기에,덴마크,스웨덴,프랑스,독일,이탈리아,노르웨이,터키,네덜란드...
# 27    예멘내각, 사우디아라비아,아랍에미리트,세네갈,수단,모로코,카타르,바레인,이집트,쿠웨...
# 28                                 필리핀공화국,미국,호주,중국,이스라엘
# 29    이라크, Rojava, 미국, 영국, 독일, 프랑스, 이탈리아, 이란, 카타르, 이...
# 30    미국, 영국, 사우디아라비아,호주,아랍에미리트,바레인,리투아니아,알바니아,쿠웨이트,...
# Name: 참전국, dtype: object

# %%
ls = len(ls_war2['참전국'])
# Out:
# 30

# %%
involving_country = ls_war2.loc[1, ['참전국']]

# %%
len(involving_country[0].split(','))
# Out:
# 3

# %%
ls = len(ls_war2['참전국'])

for idx in range(0,ls):
    involving_country = ls_war2.loc[idx+1, ['참전국']]
    ls_war2["참전국수"] = len(involving_country[0].split(','))
ls_war2.head()
# Out:
#         발발시점       종료시점            갈등이름 갈등종류                      위치  \
# 1     2001.9     2003.3       쿠르드이슬람교분쟁   민족               이라크 쿠르디스탄
# 2  2001.9.11         현재          테러와의전쟁   테러                     글로벌
# 3  2002.1.15  2015.2.24     영원한자유작전-필리핀   테러              만다나오,필리핀제도
# 4  2002.10.7         현재  영원한자유작전-아프리카의뿔   테러  아프리카의뿔,아덴만,Guardafui채널
# 5       2006         현재           탈레반반란   테러                  아프가니스탄
#
#                                                  참전국  \
# 1                             쿠르드족애국연합,쿠르디스탄민주당,미국육군
# 2  미국,영국,프랑스,러시아,알바니아,벨기에,불가리아,캐나다,크로아티아,체코공화국,덴마...
# 3                                          필리핀공화국,미국
# 4  벨기에,캐나다,덴마크,프랑스,독일,그리스,이탈리아,네덜란드,포르투갈,스페인,터키,영...
# 5  아프가니스탄,호주,크로아티아,체코공화국,그루지야,독일,이탈리아,루마니아,스페인,터키...
#
#                                                  상대국  병력_참전국 병력_상대국    전쟁규모  \
# 1                           알카에다,ISIL,아프간탈레반,파키스탄탈레반   70000   1000   71000
# 2                                                NaN     NaN    NaN     NaN
# 3                                            지하디스크그룹  110500   5300  115800
# 4  이라크,알카에다,Harkat al-Shabaad Mujahedeen, al-Itih...     500    NaN     NaN
# 5  탈레반, 파키스탄, 러시아, 중국, 카타르, 이란, 사우디아라비아, Hezb-e-I...  352000  64000  416000
#
#    참전국수  참가국수
# 1    13    13
# 2    13    13
# 3    13    13
# 4    13    13
# 5    13    13

# %%
ls = len(ls_war2['참전국'])

for idx in range(0,ls):
    involving_country = ls_war2.loc[idx+1, ['참전국']]
    count = len(involving_country[0].split(','))
    ls_war2.loc[idx+1, "참전국수"] = count
ls_war2.head()
# Out:
#         발발시점       종료시점            갈등이름 갈등종류                      위치  \
# 1     2001.9     2003.3       쿠르드이슬람교분쟁   민족               이라크 쿠르디스탄
# 2  2001.9.11         현재          테러와의전쟁   테러                     글로벌
# 3  2002.1.15  2015.2.24     영원한자유작전-필리핀   테러              만다나오,필리핀제도
# 4  2002.10.7         현재  영원한자유작전-아프리카의뿔   테러  아프리카의뿔,아덴만,Guardafui채널
# 5       2006         현재           탈레반반란   테러                  아프가니스탄
#
#                                                  참전국  \
# 1                             쿠르드족애국연합,쿠르디스탄민주당,미국육군
# 2  미국,영국,프랑스,러시아,알바니아,벨기에,불가리아,캐나다,크로아티아,체코공화국,덴마...
# 3                                          필리핀공화국,미국
# 4  벨기에,캐나다,덴마크,프랑스,독일,그리스,이탈리아,네덜란드,포르투갈,스페인,터키,영...
# 5  아프가니스탄,호주,크로아티아,체코공화국,그루지야,독일,이탈리아,루마니아,스페인,터키...
#
#                                                  상대국  병력_참전국 병력_상대국    전쟁규모  \
# 1                           알카에다,ISIL,아프간탈레반,파키스탄탈레반   70000   1000   71000
# 2                                                NaN     NaN    NaN     NaN
# 3                                            지하디스크그룹  110500   5300  115800
# 4  이라크,알카에다,Harkat al-Shabaad Mujahedeen, al-Itih...     500    NaN     NaN
# 5  탈레반, 파키스탄, 러시아, 중국, 카타르, 이란, 사우디아라비아, Hezb-e-I...  352000  64000  416000
#
#    참전국수  참가국수
# 1     3    13
# 2    48    13
# 3     2    13
# 4    38    13
# 5    15    13

# %%
ls_war2 = ls_war2.rename(columns  = {"참가국수" : "전쟁수"}, inplace=False)

ls_war2["전쟁수"] = 1
ls_war2.head()
# Out:
#         발발시점       종료시점            갈등이름 갈등종류                      위치  \
# 1     2001.9     2003.3       쿠르드이슬람교분쟁   민족               이라크 쿠르디스탄
# 2  2001.9.11         현재          테러와의전쟁   테러                     글로벌
# 3  2002.1.15  2015.2.24     영원한자유작전-필리핀   테러              만다나오,필리핀제도
# 4  2002.10.7         현재  영원한자유작전-아프리카의뿔   테러  아프리카의뿔,아덴만,Guardafui채널
# 5       2006         현재           탈레반반란   테러                  아프가니스탄
#
#                                                  참전국  \
# 1                             쿠르드족애국연합,쿠르디스탄민주당,미국육군
# 2  미국,영국,프랑스,러시아,알바니아,벨기에,불가리아,캐나다,크로아티아,체코공화국,덴마...
# 3                                          필리핀공화국,미국
# 4  벨기에,캐나다,덴마크,프랑스,독일,그리스,이탈리아,네덜란드,포르투갈,스페인,터키,영...
# 5  아프가니스탄,호주,크로아티아,체코공화국,그루지야,독일,이탈리아,루마니아,스페인,터키...
#
#                                                  상대국  병력_참전국 병력_상대국    전쟁규모  \
# 1                           알카에다,ISIL,아프간탈레반,파키스탄탈레반   70000   1000   71000
# 2                                                NaN     NaN    NaN     NaN
# 3                                            지하디스크그룹  110500   5300  115800
# 4  이라크,알카에다,Harkat al-Shabaad Mujahedeen, al-Itih...     500    NaN     NaN
# 5  탈레반, 파키스탄, 러시아, 중국, 카타르, 이란, 사우디아라비아, Hezb-e-I...  352000  64000  416000
#
#    참전국수  전쟁수
# 1     3    1
# 2    48    1
# 3     2    1
# 4    38    1
# 5    15    1

# %%
ls_war2.head()
# Out:
#         발발시점       종료시점            갈등이름 갈등종류                      위치    전쟁규모  \
# 1     2001.9     2003.3       쿠르드이슬람교분쟁   민족               이라크 쿠르디스탄   71000
# 2  2001.9.11         현재          테러와의전쟁   테러                     글로벌     NaN
# 3  2002.1.15  2015.2.24     영원한자유작전-필리핀   테러              만다나오,필리핀제도  115800
# 4  2002.10.7         현재  영원한자유작전-아프리카의뿔   테러  아프리카의뿔,아덴만,Guardafui채널     NaN
# 5       2006         현재           탈레반반란   테러                  아프가니스탄  416000
#
#    참전국수  전쟁수
# 1     3    1
# 2    48    1
# 3     2    1
# 4    38    1
# 5    15    1

# %%
ls_war2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 1 to 30
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   발발시점    30 non-null     object
#  1   종료시점    30 non-null     object
#  2   갈등이름    30 non-null     object
#  3   갈등종류    30 non-null     object
#  4   위치      30 non-null     object
#  5   전쟁규모    24 non-null     object
#  6   참전국수    30 non-null     int64
#  7   전쟁수     30 non-null     int64
# dtypes: int64(2), object(6)
# memory usage: 3.2+ KB

# %%
## 3. 데이터프레임 저장하기

# %%
ls_war2.to_csv("datas/ls_war2.csv", sep="\t")

# %%
pd.read_csv("datas/ls_war2.csv", sep='\t')
# Out:
#     Unnamed: 0        발발시점        종료시점             갈등이름 갈등종류  \
# 0            1      2001.9      2003.3        쿠르드이슬람교분쟁   민족
# 1            2   2001.9.11          현재           테러와의전쟁   테러
# 2            3   2002.1.15   2015.2.24      영원한자유작전-필리핀   테러
# 3            4   2002.10.7          현재   영원한자유작전-아프리카의뿔   테러
# 4            5        2006          현재            탈레반반란   테러
# 5            6   2003.3.20  2011.12.18            이라크전쟁   테러
# 6            7    2004.4.1      2015.8        이란-PJAK충돌   민족
# 7            8   2004.4.18   2014.9.16    예멘의 Houthi 반란   내란
# 8            9   2005.8.27          현재        파라과이인민군반란   내란
# 9           10   2006.1.25          현재        파타-하마스 분쟁   테러
# 10          11   2006.6.12   2006.8.14       2006년레바논전쟁   테러
# 11          12   2006.2.22   2008.5.11            이라크내전   내란
# 12          13  2006.12.11          현재          멕시코마약전쟁   마약
# 13          14  2006.12.30   2009.1.30           소말리아전쟁   해적
# 14          15    2007.2.6          현재   영원한자유작전-트랜스사하라   테러
# 15          16   2008.3.25          현재       2008 안주안침공   내란
# 16          17   2009.7.26          현재           보코하람반란   내란
# 17          18   2009.1.31          현재           소말리아내전   해적
# 18          19   2010.5.23   2010.6.23            킹스톤불안   마약
# 19          20   2011.2.15  2011.10.23            리비아내전   내란
# 20          21   2011.3.15          현재            시리아내전   내란
# 21          22   2011.6.17   2017.8.28    레바논에서의시리아내전파급   내란
# 22          23   2012.1.16          현재           북부말리전쟁   테러
# 23          24  2013.12.30  2017.12.09           이라크 내전   내란
# 24          25   2014.5.16  2020.10.23           리비아 내전   내란
# 25          26   2014.6.13          현재    ISIL에대한국제군사개입   테러
# 26          27   2014.9.16          현재             예멘내전   내란
# 27          28   2017.5.23  2017.10.23            마라위위기   테러
# 28          29   2017.12.9          현재            이라크반란   내란
# 29          30    2019.5.5          현재  2019-20 페르시아만위기   민족
#
#                                         위치      전쟁규모  참전국수  전쟁수
# 0                                이라크 쿠르디스탄   71000.0     3    1
# 1                                      글로벌       NaN    48    1
# 2                               만다나오,필리핀제도  115800.0     2    1
# 3                   아프리카의뿔,아덴만,Guardafui채널       NaN    38    1
# 4                                   아프가니스탄  416000.0    15    1
# 5                                      이라크       NaN    41    1
# 6                         아제르바이잔,이란,이라크,터키   17000.0     3    1
# 7                                       예멘   32000.0     7    1
# 8                                     파라과이    3650.0     3    1
# 9                                     가자지구   55000.0     3    1
# 10                                     레바논   10500.0     2    1
# 11                                     이라크  748000.0     5    1
# 12                                 멕시코,텍사스  360000.0     4    1
# 13                                    소말리아   35250.0     8    1
# 14                             사하라사막,북아프리카    5325.0    17    1
# 15                                     안주안    2500.0     7    1
# 16                                북동부나이지리아       NaN    19    1
# 17                                 소말리아,케냐   41600.0    11    1
# 18                                자메이카 킹스톤    1500.0     2    1
# 19                                     리비아   37000.0    21    1
# 20                                     시리아  144600.0    13    1
# 21                                     레바논   13500.0    19    1
# 22                                   북부 말리   24764.0    57    1
# 23                                     이라크  770000.0    22    1
# 24                                     리비아       NaN    19    1
# 25  이라크,시리아,리비아,나이지리아,아프가니스탄,북코카서스 및 동남아시아  472260.0    41    1
# 26                            예멘,남부사이디아라비아  156000.0    19    1
# 27                              마라위, 필리핀제도    7500.0     5    1
# 28                                서부및북부이라크  188900.0    13    1
# 29                                    페르스만       NaN    13    1

# %%
## 4. 전쟁종류, 규모 등 그래프로 그리기

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import font_manager
# %matplotlib inline

f_path = "C:\Windows\Fonts\malgun.ttf"
font_manager.FontProperties(fname=f_path).get_name()

from matplotlib import rc
rc('font', family='Malgun Gothic')
# %matplotlib inline

# %%
ls_war2 = pd.read_csv("datas/ls_war2.csv", sep='\t')
ls_war2 = ls_war2.drop(["Unnamed: 0"], axis=1)
ls_war2.head(10)
# Out:
#         발발시점        종료시점            갈등이름 갈등종류                      위치  \
# 0     2001.9      2003.3       쿠르드이슬람교분쟁   민족               이라크 쿠르디스탄
# 1  2001.9.11          현재          테러와의전쟁   테러                     글로벌
# 2  2002.1.15   2015.2.24     영원한자유작전-필리핀   테러              만다나오,필리핀제도
# 3  2002.10.7          현재  영원한자유작전-아프리카의뿔   테러  아프리카의뿔,아덴만,Guardafui채널
# 4       2006          현재           탈레반반란   테러                  아프가니스탄
# 5  2003.3.20  2011.12.18           이라크전쟁   테러                     이라크
# 6   2004.4.1      2015.8       이란-PJAK충돌   민족        아제르바이잔,이란,이라크,터키
# 7  2004.4.18   2014.9.16   예멘의 Houthi 반란   내란                      예멘
# 8  2005.8.27          현재       파라과이인민군반란   내란                    파라과이
# 9  2006.1.25          현재       파타-하마스 분쟁   테러                    가자지구
#
#        전쟁규모  참전국수  전쟁수
# 0   71000.0     3    1
# 1       NaN    48    1
# 2  115800.0     2    1
# 3       NaN    38    1
# 4  416000.0    15    1
# 5       NaN    41    1
# 6   17000.0     3    1
# 7   32000.0     7    1
# 8    3650.0     3    1
# 9   55000.0     3    1

# %%
ls_war2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   발발시점    30 non-null     object
#  1   종료시점    30 non-null     object
#  2   갈등이름    30 non-null     object
#  3   갈등종류    30 non-null     object
#  4   위치      30 non-null     object
#  5   전쟁규모    24 non-null     float64
#  6   참전국수    30 non-null     int64
#  7   전쟁수     30 non-null     int64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 2.0+ KB

# %%
lw2_gb1 = ls_war2.groupby("갈등종류").agg("sum")["참전국수"].reset_index()
lw2_gb1
# Out:
#   갈등종류  참전국수
# 0   내란   167
# 1   마약     6
# 2   민족    19
# 3   테러   269
# 4   해적    19

# %%
lw2_gb2 = ls_war2.groupby("갈등종류").agg("sum")["참전국수"].reset_index()
lw2_gb2
# Out:
#   갈등종류  참전국수
# 0   내란   167
# 1   마약     6
# 2   민족    19
# 3   테러   269
# 4   해적    19

# %%
lw2_gb3 = ls_war2.groupby("갈등종류").agg("sum")["전쟁규모"].reset_index()
lw2_gb3
# Out:
#   갈등종류       전쟁규모
# 0   내란  2096150.0
# 1   마약   361500.0
# 2   민족    88000.0
# 3   테러  1107149.0
# 4   해적    76850.0

# %%
### 데이터요약

# %%
result_df=lw2_gb1.merge(lw2_gb2, left_on="갈등종류", right_on="갈등종류")
result_df=result_df.merge(lw2_gb3, left_on="갈등종류", right_on="갈등종류")
result_df
# Out:
#   갈등종류  전쟁수  참전국수       전쟁규모
# 0   내란   12   167  2096150.0
# 1   마약    2     6   361500.0
# 2   민족    3    19    88000.0
# 3   테러   11   269  1107149.0
# 4   해적    2    19    76850.0

# %%
sns.pairplot(result_df, hue="갈등종류")
plt.show()

# %%
# lmplot

# %%
sns.lmplot("참전국수", "전쟁규모", data=result_df, hue="갈등종류", fit_reg=False )
plt.show()

# %%
x_datas = result_df["갈등종류"]
y1_datas = result_df["참전국수"]
plt.plot(x_datas, y1_datas)
plt.show()

# %%
x_datas = result_df["갈등종류"]
y2_datas = result_df["전쟁규모"]
plt.plot(x_datas, y2_datas)
plt.show()

# %%
x_datas = result_df["갈등종류"]
y3_datas = result_df["전쟁수"]
plt.plot(x_datas, y3_datas)
plt.show()

# %%
plt.bar(x_datas, y1_datas, width=0.4)
plt.show()

# %%
plt.bar(x_datas, y2_datas, width=0.4)
plt.show()

# %%
plt.bar(x_datas, y3_datas, width=0.4)
plt.show()
